# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Figure 4

# %%
df4 = pd.read_csv('./data/result/reproduce_fig4.csv')

# %%
df4.decoder.unique()
# Out:
# array(['BPOSD', 'MLE', 'MWPM'], dtype=object)

# %%
df4.metric.unique()
# Out:
# array(['walltime_seconds', 'logical_accuracy'], dtype=object)

# %%
df4.distance.unique()
# Out:
# array([3, 5])

# %%
df4.depth.unique()
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
df4.head()
# Out:
#   decoder  distance  depth  circuit_type_index            metric     value
# 0   BPOSD         3      2                   3  walltime_seconds  0.004947
# 1   BPOSD         3      2                   3  walltime_seconds  0.004932
# 2   BPOSD         3      2                   3  walltime_seconds  0.004944
# 3   BPOSD         3      2                   3  walltime_seconds  0.004185
# 4   BPOSD         3      2                   3  walltime_seconds  0.004194

# %%
df4.circuit_type_index.unique()
# Out:
# array([3])

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df4[(df4.metric == 'logical_accuracy') & (df4.distance == 3)], x='depth', y='value', hue='decoder',hue_order='MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.title('d = 3, Type I circuits, Logical Accuracy')
ax=plt.subplot(122)
sns.lineplot(df4[(df4.metric == 'logical_accuracy') & (df4.distance == 5)], x='depth', y='value', hue='decoder',hue_order='MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.title('d = 5, Type I circuits, Logical Accuracy')

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)

sns.lineplot(df4[(df4.metric == 'walltime_seconds') & (df4.distance == 3)], x='depth', y='value', hue='decoder', hue_order='MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.title('d = 3, Type I circuits, Wall time')

ax=plt.subplot(122)
sns.lineplot(df4[(df4.metric == 'walltime_seconds') & (df4.distance == 5)], x='depth', y='value', hue='decoder', hue_order='MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.title('d = 5, Type I circuits, Wall time')
# Out:
# Text(0.5, 1.0, 'd = 5, Type I circuits, Wall time')

# %% [markdown]
# ## Figure 5

# %%
df5 = df[df.circuit_type_index == 4]

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df5[(df5.metric == 'logical_accuracy') & (df5.distance == 3)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')

plt.title('d = 3, Type II circuits, Logical Accuracy')
ax=plt.subplot(122)
sns.lineplot(df5[(df5.metric == 'logical_accuracy') & (df5.distance == 5)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')

plt.title('d = 5, Type II circuits, Logical Accuracy')
# Out:
# Text(0.5, 1.0, 'd = 5, Type II circuits, Logical Accuracy')

# %%
df5.head()
# Out:
#    decoder  distance  depth  circuit_type_index            metric     value
# 60   BPOSD         3      4                   4  walltime_seconds  0.004107
# 61   BPOSD         3      4                   4  walltime_seconds  0.010069
# 62   BPOSD         3      4                   4  walltime_seconds  0.007911
# 63   BPOSD         3      4                   4  walltime_seconds  0.005687
# 64   BPOSD         3      4                   4  walltime_seconds  0.008518

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df5[(df5.metric == 'walltime_seconds') & (df5.distance == 3)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
# plt.ylim(1e-3, 10)
plt.title('d = 3, Type II circuits, Wall time')
ax=plt.subplot(122)
sns.lineplot(df5[(df5.metric == 'walltime_seconds') & (df5.distance == 5)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
# plt.ylim(1e-3, 10)
plt.title('d = 5, Type II circuits, Wall time')
# Out:
# Text(0.5, 1.0, 'd = 5, Type II circuits, Wall time')
