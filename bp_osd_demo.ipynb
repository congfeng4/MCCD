# %% [markdown]
# # BP-OSD Decoding with stimbposd

# %%
import stim
import numpy as np
from stimbposd import BPOSD

num_shots = 100
d = 4
p = 0.007
circuit = stim.Circuit.generated(
    "surface_code:unrotated_memory_z",
    rounds=d,
    distance=d,
    before_round_data_depolarization=p,
    before_measure_flip_probability=p,
    after_reset_flip_probability=p,
    after_clifford_depolarization=p
)

sampler = circuit.compile_detector_sampler()
shots, observables = sampler.sample(num_shots, separate_observables=True)

decoder = BPOSD(circuit.detector_error_model(), max_bp_iters=20)

predicted_observables = decoder.decode_batch(shots)
num_mistakes = np.sum(np.any(predicted_observables != observables, axis=1))

print(f"{num_mistakes}/{num_shots}")
# Out:
# 3/100

# %% [markdown]
# 3 36
#
# 2 8
#
# 4 96

# %%
shots.shape
# Out:
# (100, 8)

# %% [markdown]
# det_per_round = (d − 1)²        # 内部 (d-1)×(d-1) 个 face
#
# num_detectors = r × (d − 1)²

# %%
circuit.num_detectors
# Out:
# 96

# %%
type(sampler)
# Out:
# stim._stim_polyfill.CompiledDetectorSampler

# %%
circuit
# Out:
# stim.Circuit('''
#     QUBIT_COORDS(1, 1) 1
#     QUBIT_COORDS(2, 0) 2
#     QUBIT_COORDS(3, 1) 3
#     QUBIT_COORDS(5, 1) 5
#     QUBIT_COORDS(6, 0) 6
#     QUBIT_COORDS(7, 1) 7
#     QUBIT_COORDS(9, 1) 9
#     QUBIT_COORDS(1, 3) 12
#     QUBIT_COORDS(2, 2) 13
#     QUBIT_COORDS(3, 3) 14
#     QUBIT_COORDS(4, 2) 15
#     QUBIT_COORDS(5, 3) 16
#     QUBIT_COORDS(6, 2) 17
#     QUBIT_COORDS(7, 3) 18
#     QUBIT_COORDS(8, 2) 19
#     QUBIT_COORDS(9, 3) 20
#     QUBIT_COORDS(10, 2) 21
#     QUBIT_COORDS(0, 4) 22
#     QUBIT_COORDS(1, 5) 23
#     QUBIT_COORDS(2, 4) 24
#     QUBIT_COORDS(3, 5) 25
#     QUBIT_COORDS(4, 4) 26
#     QUBIT_COORDS(5, 5) 27
#     QUBIT_COORDS(6, 4) 28
#     QUBIT_COORDS(7, 5) 29
#     QUBIT_COORDS(8, 4) 30
#     QUBIT_COORDS(9, 5) 31
#     QUBIT_COORDS(1, 7) 34
#     QUBIT_COORDS(2, 6) 35
#     QUBIT_COORDS(3, 7) 36
#     QUBIT_COORDS(4, 6) 37
#     QUBIT_COORDS(5, 7) 38
#     QUBIT_COORDS(6, 6) 39
#     QUBIT_COORDS(7, 7) 40
#     QUBIT_COORDS(8, 6) 41
#     QUBIT_COORDS(9, 7) 42
#     QUBIT_COORDS(10, 6) 43
#     QUBIT_COORDS(0, 8) 44
#     QUBIT_COORDS(1, 9) 45
#     QUBIT_COORDS(2, 8) 46
#     QUBIT_COORDS(3, 9) 47
#     QUBIT_COORDS(4, 8) 48
#     QUBIT_COORDS(5, 9) 49
#     QUBIT_COORDS(6, 8) 50
#     QUBIT_COORDS(7, 9) 51
#     QUBIT_COORDS(8, 8) 52
#     QUBIT_COORDS(9, 9) 53
#     QUBIT_COORDS(4, 10) 59
#     QUBIT_COORDS(8, 10) 63
#     RX 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#     Z_ERROR(0.007) 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#     R 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#     X_ERROR(0.007) 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#     TICK
#     DEPOLARIZE1(0.007) 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#     H 2 6 15 19 24 28 37 41 46 50 59 63
#     DEPOLARIZE1(0.007) 2 6 15 19 24 28 37 41 46 50 59 63
#     TICK
#     CX 2 3 24 25 46 47 15 16 37 38 6 7 28 29 50 51 19 20 41 42 23 22 45 44 14 13 36 35 27 26 49 48 18 17 40 39 31 30 53 52
#     DEPOLARIZE2(0.007) 2 3 24 25 46 47 15 16 37 38 6 7 28 29 50 51 19 20 41 42 23 22 45 44 14 13 36 35 27 26 49 48 18 17 40 39 31 30 53 52
#     TICK
#     CX 2 1 24 23 46 45 15 14 37 36 6 5 28 27 50 49 19 18 41 40 12 22 34 44 3 13 25 35 16 26 38 48 7 17 29 39 20 30 42 52
#     DEPOLARIZE2(0.007) 2 1 24 23 46 45 15 14 37 36 6 5 28 27 50 49 19 18 41 40 12 22 34 44 3 13 25 35 16 26 38 48 7 17 29 39 20 30 42 52
#     TICK
#     CX 24 14 46 36 15 5 37 27 59 49 28 18 50 40 19 9 41 31 63 53 12 13 34 35 25 26 47 48 16 17 38 39 29 30 51 52 20 21 42 43
#     DEPOLARIZE2(0.007) 24 14 46 36 15 5 37 27 59 49 28 18 50 40 19 9 41 31 63 53 12 13 34 35 25 26 47 48 16 17 38 39 29 30 51 52 20 21 42 43
#     TICK
#     CX 24 12 46 34 15 3 37 25 59 47 28 16 50 38 19 7 41 29 63 51 1 13 23 35 14 26 36 48 5 17 27 39 18 30 40 52 9 21 31 43
#     DEPOLARIZE2(0.007) 24 12 46 34 15 3 37 25 59 47 28 16 50 38 19 7 41 29 63 51 1 13 23 35 14 26 36 48 5 17 27 39 18 30 40 52 9 21 31 43
#     TICK
#     H 2 6 15 19 24 28 37 41 46 50 59 63
#     DEPOLARIZE1(0.007) 2 6 15 19 24 28 37 41 46 50 59 63
#     TICK
#     X_ERROR(0.007) 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#     MR 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#     X_ERROR(0.007) 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#     DETECTOR(2, 0, 0) rec[-24]
#     DETECTOR(2, 4, 0) rec[-16]
#     DETECTOR(2, 8, 0) rec[-6]
#     DETECTOR(4, 2, 0) rec[-21]
#     DETECTOR(4, 6, 0) rec[-11]
#     DETECTOR(4, 10, 0) rec[-2]
#     DETECTOR(6, 0, 0) rec[-23]
#     DETECTOR(6, 4, 0) rec[-14]
#     DETECTOR(6, 8, 0) rec[-4]
#     DETECTOR(8, 2, 0) rec[-19]
#     DETECTOR(8, 6, 0) rec[-9]
#     DETECTOR(8, 10, 0) rec[-1]
#     REPEAT 4 {
#         TICK
#         DEPOLARIZE1(0.007) 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#         H 2 6 15 19 24 28 37 41 46 50 59 63
#         DEPOLARIZE1(0.007) 2 6 15 19 24 28 37 41 46 50 59 63
#         TICK
#         CX 2 3 24 25 46 47 15 16 37 38 6 7 28 29 50 51 19 20 41 42 23 22 45 44 14 13 36 35 27 26 49 48 18 17 40 39 31 30 53 52
#         DEPOLARIZE2(0.007) 2 3 24 25 46 47 15 16 37 38 6 7 28 29 50 51 19 20 41 42 23 22 45 44 14 13 36 35 27 26 49 48 18 17 40 39 31 30 53 52
#         TICK
#         CX 2 1 24 23 46 45 15 14 37 36 6 5 28 27 50 49 19 18 41 40 12 22 34 44 3 13 25 35 16 26 38 48 7 17 29 39 20 30 42 52
#         DEPOLARIZE2(0.007) 2 1 24 23 46 45 15 14 37 36 6 5 28 27 50 49 19 18 41 40 12 22 34 44 3 13 25 35 16 26 38 48 7 17 29 39 20 30 42 52
#         TICK
#         CX 24 14 46 36 15 5 37 27 59 49 28 18 50 40 19 9 41 31 63 53 12 13 34 35 25 26 47 48 16 17 38 39 29 30 51 52 20 21 42 43
#         DEPOLARIZE2(0.007) 24 14 46 36 15 5 37 27 59 49 28 18 50 40 19 9 41 31 63 53 12 13 34 35 25 26 47 48 16 17 38 39 29 30 51 52 20 21 42 43
#         TICK
#         CX 24 12 46 34 15 3 37 25 59 47 28 16 50 38 19 7 41 29 63 51 1 13 23 35 14 26 36 48 5 17 27 39 18 30 40 52 9 21 31 43
#         DEPOLARIZE2(0.007) 24 12 46 34 15 3 37 25 59 47 28 16 50 38 19 7 41 29 63 51 1 13 23 35 14 26 36 48 5 17 27 39 18 30 40 52 9 21 31 43
#         TICK
#         H 2 6 15 19 24 28 37 41 46 50 59 63
#         DEPOLARIZE1(0.007) 2 6 15 19 24 28 37 41 46 50 59 63
#         TICK
#         X_ERROR(0.007) 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#         MR 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#         X_ERROR(0.007) 2 6 13 15 17 19 21 22 24 26 28 30 35 37 39 41 43 44 46 48 50 52 59 63
#         SHIFT_COORDS(0, 0, 1)
#         DETECTOR(2, 0, 0) rec[-24] rec[-48]
#         DETECTOR(6, 0, 0) rec[-23] rec[-47]
#         DETECTOR(2, 2, 0) rec[-22] rec[-46]
#         DETECTOR(4, 2, 0) rec[-21] rec[-45]
#         DETECTOR(6, 2, 0) rec[-20] rec[-44]
#         DETECTOR(8, 2, 0) rec[-19] rec[-43]
#         DETECTOR(10, 2, 0) rec[-18] rec[-42]
#         DETECTOR(0, 4, 0) rec[-17] rec[-41]
#         DETECTOR(2, 4, 0) rec[-16] rec[-40]
#         DETECTOR(4, 4, 0) rec[-15] rec[-39]
#         DETECTOR(6, 4, 0) rec[-14] rec[-38]
#         DETECTOR(8, 4, 0) rec[-13] rec[-37]
#         DETECTOR(2, 6, 0) rec[-12] rec[-36]
#         DETECTOR(4, 6, 0) rec[-11] rec[-35]
#         DETECTOR(6, 6, 0) rec[-10] rec[-34]
#         DETECTOR(8, 6, 0) rec[-9] rec[-33]
#         DETECTOR(10, 6, 0) rec[-8] rec[-32]
#         DETECTOR(0, 8, 0) rec[-7] rec[-31]
#         DETECTOR(2, 8, 0) rec[-6] rec[-30]
#         DETECTOR(4, 8, 0) rec[-5] rec[-29]
#         DETECTOR(6, 8, 0) rec[-4] rec[-28]
#         DETECTOR(8, 8, 0) rec[-3] rec[-27]
#         DETECTOR(4, 10, 0) rec[-2] rec[-26]
#         DETECTOR(8, 10, 0) rec[-1] rec[-25]
#     }
#     Z_ERROR(0.007) 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#     MX 1 3 5 7 9 12 14 16 18 20 23 25 27 29 31 34 36 38 40 42 45 47 49 51 53
#     DETECTOR(2, 0, 1) rec[-24] rec[-25] rec[-49]
#     DETECTOR(2, 4, 1) rec[-14] rec[-15] rec[-19] rec[-20] rec[-41]
#     DETECTOR(2, 8, 1) rec[-4] rec[-5] rec[-9] rec[-10] rec[-31]
#     DETECTOR(4, 2, 1) rec[-18] rec[-19] rec[-23] rec[-24] rec[-46]
#     DETECTOR(4, 6, 1) rec[-8] rec[-9] rec[-13] rec[-14] rec[-36]
#     DETECTOR(4, 10, 1) rec[-3] rec[-4] rec[-27]
#     DETECTOR(6, 0, 1) rec[-22] rec[-23] rec[-48]
#     DETECTOR(6, 4, 1) rec[-12] rec[-13] rec[-17] rec[-18] rec[-39]
#     DETECTOR(6, 8, 1) rec[-2] rec[-3] rec[-7] rec[-8] rec[-29]
#     DETECTOR(8, 2, 1) rec[-16] rec[-17] rec[-21] rec[-22] rec[-44]
#     DETECTOR(8, 6, 1) rec[-6] rec[-7] rec[-11] rec[-12] rec[-34]
#     DETECTOR(8, 10, 1) rec[-1] rec[-2] rec[-26]
#     OBSERVABLE_INCLUDE(0) rec[-5] rec[-10] rec[-15] rec[-20] rec[-25]
# ''')
