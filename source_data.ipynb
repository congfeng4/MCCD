# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Figure 4

# %%
df4 = pd.read_csv('./source_data/figure_4_source_data.csv')

# %%
df4.metric.unique()
# Out:
# array(['logical_accuracy', 'wall_time_seconds'], dtype=object)

# %%
df4.distance.unique()
# Out:
# array([3, 5])

# %%
df4.head()
# Out:
#    circuit_type_index  distance decoder            metric  depth  trial  \
# 0                   1         3   BPOSD  logical_accuracy      2      0
# 1                   1         3   BPOSD  logical_accuracy      2      1
# 2                   1         3   BPOSD  logical_accuracy      2      2
# 3                   1         3   BPOSD  logical_accuracy      2      3
# 4                   1         3   BPOSD  logical_accuracy      2      4
#
#       value
# 0  0.934766
# 1  0.938281
# 2  0.937891
# 3  0.936328
# 4  0.938672

# %%
df4.circuit_type_index.unique()
# Out:
# array([1])

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df4[(df4.metric == 'logical_accuracy') & (df4.distance == 3)], x='depth', y='value', hue='decoder',hue_order='MCCD MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.title('d = 3, Type I circuits, Logical Accuracy')
plt.ylim(0.5, 1.0)
ax=plt.subplot(122)
sns.lineplot(df4[(df4.metric == 'logical_accuracy') & (df4.distance == 5)], x='depth', y='value', hue='decoder',hue_order='MCCD MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.title('d = 5, Type I circuits, Logical Accuracy')
plt.ylim(0.5, 1.0)
# Out:
# (0.5, 1.0)

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)

sns.lineplot(df4[(df4.metric == 'wall_time_seconds') & (df4.distance == 3)], x='depth', y='value', hue='decoder', hue_order='MCCD MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.ylim(1e-9, 1)
plt.title('d = 3, Type I circuits, Wall time')

ax=plt.subplot(122)
sns.lineplot(df4[(df4.metric == 'wall_time_seconds') & (df4.distance == 5)], x='depth', y='value', hue='decoder', hue_order='MCCD MLE BPOSD MWPM'.split(),
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.ylim(1e-9, 1)
plt.title('d = 5, Type I circuits, Wall time')
# Out:
# Text(0.5, 1.0, 'd = 5, Type I circuits, Wall time')

# %% [markdown]
# ## Figure 5

# %%
df5 = pd.read_csv('./source_data/figure_5_source_data.csv')

# %%
df5.head()
# Out:
#    circuit_type_index  distance decoder            metric  depth  trial  \
# 0                   2         3   BPOSD  logical_accuracy      4      0
# 1                   2         3   BPOSD  logical_accuracy      4      1
# 2                   2         3   BPOSD  logical_accuracy      4      2
# 3                   2         3   BPOSD  logical_accuracy      4      3
# 4                   2         3   BPOSD  logical_accuracy      4      4
#
#       value
# 0  0.914062
# 1  0.930859
# 2  0.910937
# 3  0.924219
# 4  0.914844

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df5[(df5.metric == 'logical_accuracy') & (df5.distance == 3)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.ylim(0.5, 1.0)

plt.title('d = 3, Type II circuits, Logical Accuracy')
ax=plt.subplot(122)
sns.lineplot(df5[(df5.metric == 'logical_accuracy') & (df5.distance == 5)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('logical_accuracy')
plt.ylim(0.5, 1.0)

plt.title('d = 5, Type II circuits, Logical Accuracy')
# Out:
# Text(0.5, 1.0, 'd = 5, Type II circuits, Logical Accuracy')

# %%
plt.figure(figsize=(12,5))
ax=plt.subplot(121)
sns.lineplot(df5[(df5.metric == 'wall_time_seconds') & (df5.distance == 3)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.ylim(1e-3, 10)
plt.title('d = 3, Type II circuits, Wall time')
ax=plt.subplot(122)
sns.lineplot(df5[(df5.metric == 'wall_time_seconds') & (df5.distance == 5)], x='depth', y='value', hue='decoder',
             errorbar=None, style='decoder', markers=True, dashes=False, markersize=10, linewidth=1, ax=ax)
plt.ylabel('Wall time (s)')
plt.yscale('log')
plt.ylim(1e-3, 10)
plt.title('d = 5, Type II circuits, Wall time')
# Out:
# Text(0.5, 1.0, 'd = 5, Type II circuits, Wall time')

# %%
df5[df5.metric == 'wall_time_seconds'].value
# Out:
# 180     0.002503
# 181     0.001905
# 182     0.001791
# 183     0.001862
# 184     0.001856
#           ...
# 2155    1.742112
# 2156    1.813951
# 2157    1.758576
# 2158    1.703202
# 2159    1.747591
# Name: value, Length: 1080, dtype: float64
