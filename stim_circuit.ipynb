# %%
from stim import Circuit

# %%
circuit = Circuit.from_file('./data/algorithmic_fault_tolerance_data-zenodo-v1/circuits/ghz/figure_3_lattice_surgery_11.stim')

# %%
sampler = circuit.compile_detector_sampler()

# %%
circuit.num_detectors
# Out:
# 1075

# %%
circuit.num_observables
# Out:
# 0

# %%
import qecstruct

# %%
sampler.sample(5).shape
# Out:
# (5, 1075)

# %%
dir(qecstruct)
# Out:
# ['BinaryMatrix',
#  'BinarySymmetricChannel',
#  'BinaryVector',
#  'CssCode',
#  'LinearCode',
#  'Pauli',
#  'PauliOperator',
#  'Rng',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'hamming_code',
#  'hypergraph_product',
#  'qecstruct',
#  'random_regular_code',
#  'repetition_code',
#  'shor_code',
#  'steane_code']

# %%
import stimzx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import stimzx
#
# ModuleNotFoundError: No module named 'stimzx'
